# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/91970/OneDrive/Pictures/Saved Pictures/abalone.csv")

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.isna().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
df["Sex"].unique()
# Out:
# array(['M', 'F', 'I'], dtype=object)

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
sns.boxplot(df["Length"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Length'>

# %%
sns.distplot(df["Length"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Length', ylabel='Density'>

# %%
df["Length"].skew()
# Out:
# -0.639873268981801

# %%
df["Length"].describe()
# Out:
# count    4177.000000
# mean        0.523992
# std         0.120093
# min         0.075000
# 25%         0.450000
# 50%         0.545000
# 75%         0.615000
# max         0.815000
# Name: Length, dtype: float64

# %%
iqr=0.615000-0.450000

# %%
iqr
# Out:
# 0.16499999999999998

# %%
lower=0.450000-(1.5*iqr)

# %%
lower
# Out:
# 0.20250000000000004

# %%
df[df["Length"]<lower]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 148    I   0.175     0.130   0.055        0.0315          0.0105
# 149    I   0.170     0.130   0.095        0.0300          0.0130
# 236    I   0.075     0.055   0.010        0.0020          0.0010
# 237    I   0.130     0.100   0.030        0.0130          0.0045
# 238    I   0.110     0.090   0.030        0.0080          0.0025
# 239    I   0.160     0.120   0.035        0.0210          0.0075
# 305    I   0.200     0.145   0.060        0.0370          0.0125
# 306    I   0.165     0.120   0.030        0.0215          0.0070
# 321    I   0.190     0.145   0.040        0.0380          0.0165
# 465    I   0.175     0.125   0.050        0.0235          0.0080
# 523    M   0.200     0.140   0.055        0.0350          0.0145
# 525    M   0.175     0.125   0.040        0.0240          0.0095
# 526    M   0.155     0.110   0.040        0.0155          0.0065
# ...

# %%
upper=0.615000+(1.5*iqr)

# %%
upper
# Out:
# 0.8624999999999999

# %%
df[df["Length"]>upper]
# Out:
# Empty DataFrame
# Columns: [Sex, Length, Diameter, Height, Whole weight, Shucked weight, Viscera weight, Shell weight, Rings]
# Index: []

# %%
df[(df["Length"]<lower)|(df["Length"]>upper)]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 148    I   0.175     0.130   0.055        0.0315          0.0105
# 149    I   0.170     0.130   0.095        0.0300          0.0130
# 236    I   0.075     0.055   0.010        0.0020          0.0010
# 237    I   0.130     0.100   0.030        0.0130          0.0045
# 238    I   0.110     0.090   0.030        0.0080          0.0025
# 239    I   0.160     0.120   0.035        0.0210          0.0075
# 305    I   0.200     0.145   0.060        0.0370          0.0125
# 306    I   0.165     0.120   0.030        0.0215          0.0070
# 321    I   0.190     0.145   0.040        0.0380          0.0165
# 465    I   0.175     0.125   0.050        0.0235          0.0080
# 523    M   0.200     0.140   0.055        0.0350          0.0145
# 525    M   0.175     0.125   0.040        0.0240          0.0095
# 526    M   0.155     0.110   0.040        0.0155          0.0065
# ...

# %%
df["Length"].map(lambda x:lower if x<lower else upper if x>upper else x)
# Out:
# 0       0.455
# 1       0.350
# 2       0.530
# 3       0.440
# 4       0.330
#         ...
# 4172    0.565
# 4173    0.590
# 4174    0.600
# 4175    0.625
# 4176    0.710
# Name: Length, Length: 4177, dtype: float64

# %%
df["Length"] = df["Length"].map(lambda x:lower if x<lower else upper if x>upper else x)

# %%
df[(df["Length"]<lower)|(df["Length"]>upper)]
# Out:
# Empty DataFrame
# Columns: [Sex, Length, Diameter, Height, Whole weight, Shucked weight, Viscera weight, Shell weight, Rings]
# Index: []

# %%
df["Diameter"].describe()
# Out:
# count    4177.000000
# mean        0.407881
# std         0.099240
# min         0.055000
# 25%         0.350000
# 50%         0.425000
# 75%         0.480000
# max         0.650000
# Name: Diameter, dtype: float64

# %%
sns.boxplot(df["Diameter"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Diameter'>

# %%
sns.distplot(df["Diameter"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Diameter', ylabel='Density'>

# %%
df["Diameter"].skew()
# Out:
# -0.6091981423290918

# %%
iqr1=0.480000-0.350000

# %%
iqr1
# Out:
# 0.13

# %%
lowerd=0.350000-(1.5*iqr1)

# %%
lowerd
# Out:
# 0.15499999999999997

# %%
upperd=0.480000+(1.5*iqr1)

# %%
upperd
# Out:
# 0.675

# %%
df[df["Diameter"]<lowerd]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 43     I  0.2050     0.150   0.055        0.0420          0.0255
# 44     I  0.2100     0.150   0.050        0.0420          0.0175
# 148    I  0.2025     0.130   0.055        0.0315          0.0105
# 149    I  0.2025     0.130   0.095        0.0300          0.0130
# 236    I  0.2025     0.055   0.010        0.0020          0.0010
# 237    I  0.2025     0.100   0.030        0.0130          0.0045
# 238    I  0.2025     0.090   0.030        0.0080          0.0025
# 239    I  0.2025     0.120   0.035        0.0210          0.0075
# 305    I  0.2025     0.145   0.060        0.0370          0.0125
# 306    I  0.2025     0.120   0.030        0.0215          0.0070
# 321    I  0.2025     0.145   0.040        0.0380          0.0165
# 465    I  0.2025     0.125   0.050        0.0235          0.0080
# 520    M  0.2100     0.150   0.050        0.0385          0.0155
# ...

# %%
df[df["Diameter"]>upperd]
# Out:
# Empty DataFrame
# Columns: [Sex, Length, Diameter, Height, Whole weight, Shucked weight, Viscera weight, Shell weight, Rings]
# Index: []

# %%
df[(df["Diameter"]<lowerd)|(df["Diameter"]>upperd)]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 43     I  0.2050     0.150   0.055        0.0420          0.0255
# 44     I  0.2100     0.150   0.050        0.0420          0.0175
# 148    I  0.2025     0.130   0.055        0.0315          0.0105
# 149    I  0.2025     0.130   0.095        0.0300          0.0130
# 236    I  0.2025     0.055   0.010        0.0020          0.0010
# 237    I  0.2025     0.100   0.030        0.0130          0.0045
# 238    I  0.2025     0.090   0.030        0.0080          0.0025
# 239    I  0.2025     0.120   0.035        0.0210          0.0075
# 305    I  0.2025     0.145   0.060        0.0370          0.0125
# 306    I  0.2025     0.120   0.030        0.0215          0.0070
# 321    I  0.2025     0.145   0.040        0.0380          0.0165
# 465    I  0.2025     0.125   0.050        0.0235          0.0080
# 520    M  0.2100     0.150   0.050        0.0385          0.0155
# ...

# %%
df["Diameter"] = df["Diameter"].map(lambda x:lowerd if x<lowerd else upperd if x>upperd else x)

# %%
df[(df["Diameter"]<lowerd)|(df["Diameter"]>upperd)]
# Out:
# Empty DataFrame
# Columns: [Sex, Length, Diameter, Height, Whole weight, Shucked weight, Viscera weight, Shell weight, Rings]
# Index: []

# %%
sns.boxplot(df["Height"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Height'>

# %%
sns.distplot(df["Height"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
df["Height"].skew()
# Out:
# 3.1288173790659615

# %%
df["Height"].describe()
# Out:
# count    4177.000000
# mean        0.139516
# std         0.041827
# min         0.000000
# 25%         0.115000
# 50%         0.140000
# 75%         0.165000
# max         1.130000
# Name: Height, dtype: float64

# %%
iqr2=0.165000-0.115000

# %%
iqr2
# Out:
# 0.05

# %%
lowerr=0.115000-(1.5*iqr2)

# %%
lowerr
# Out:
# 0.039999999999999994

# %%
upperr=0.165000+(1.5*iqr2)

# %%
upperr
# Out:
# 0.24000000000000002

# %%
df["Height"] = df["Height"].map(lambda x:lowerr if x<lowerr else upperr if x>upperr else x)

# %%
sns.boxplot(df["Whole weight"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Whole weight'>

# %%
sns.distplot(df["Whole weight"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Whole weight', ylabel='Density'>

# %%
df["Whole weight"].skew()
# Out:
# 0.5309585632523087

# %%
df["Whole weight"].describe()
# Out:
# count    4177.000000
# mean        0.828742
# std         0.490389
# min         0.002000
# 25%         0.441500
# 50%         0.799500
# 75%         1.153000
# max         2.825500
# Name: Whole weight, dtype: float64

# %%
iqr3=1.153000-0.441500

# %%
iqr3
# Out:
# 0.7115

# %%
low=0.441500-(1.5*iqr3)

# %%
low
# Out:
# -0.62575

# %%
upp=1.153000+(1.5*iqr3)

# %%
upp
# Out:
# 2.22025

# %%
df[(df["Whole weight"]<low)|(df["Whole weight"]>upp)]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 165    M   0.725     0.570   0.190        2.5500          1.0705
# 358    M   0.745     0.585   0.215        2.4990          0.9265
# 891    M   0.730     0.595   0.230        2.8255          1.1465
# 1051   F   0.735     0.600   0.220        2.5550          1.1335
# 1052   M   0.765     0.600   0.220        2.3020          1.0070
# 1193   M   0.700     0.575   0.190        2.2730          1.0950
# 1206   F   0.750     0.570   0.210        2.2360          1.1090
# 1207   F   0.755     0.625   0.210        2.5050          1.1965
# 1209   F   0.780     0.630   0.215        2.6570          1.4880
# 1426   F   0.745     0.570   0.215        2.2500          1.1565
# 1427   F   0.750     0.610   0.235        2.5085          1.2320
# 1428   F   0.815     0.650   0.240        2.2550          0.8905
# 1761   M   0.750     0.595   0.205        2.2205          1.0830
# ...

# %%
df["Whole weight"] = df["Whole weight"].map(lambda x:low if x<low else upp if x>upp else x)

# %%
sns.boxplot(df["Shucked weight"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Shucked weight'>

# %%
sns.distplot(df["Shucked weight"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Shucked weight', ylabel='Density'>

# %%
df["Shucked weight"].skew()
# Out:
# 0.7190979217612694

# %%
df["Shucked weight"].describe()
# Out:
# count    4177.000000
# mean        0.359367
# std         0.221963
# min         0.001000
# 25%         0.186000
# 50%         0.336000
# 75%         0.502000
# max         1.488000
# Name: Shucked weight, dtype: float64

# %%
iqr4= 0.502000-0.186000

# %%
iqr4
# Out:
# 0.316

# %%
lowe=0.186000-(1.5*iqr4)

# %%
lowe
# Out:
# -0.288

# %%
uppe=0.502000+(1.5*iqr4)

# %%
uppe
# Out:
# 0.976

# %%
df[(df["Shucked weight"]<lowe)|(df["Shucked weight"]>uppe)]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 165    M   0.725     0.570   0.190       2.22025          1.0705
# 891    M   0.730     0.595   0.230       2.22025          1.1465
# 1048   M   0.710     0.565   0.205       2.19800          1.0120
# 1051   F   0.735     0.600   0.220       2.22025          1.1335
# 1052   M   0.765     0.600   0.220       2.22025          1.0070
# 1193   M   0.700     0.575   0.190       2.22025          1.0950
# 1197   M   0.715     0.550   0.190       2.00450          1.0465
# 1199   F   0.720     0.580   0.195       2.10300          1.0265
# 1202   M   0.725     0.505   0.185       1.97800          1.0260
# 1206   F   0.750     0.570   0.210       2.22025          1.1090
# 1207   F   0.755     0.625   0.210       2.22025          1.1965
# 1209   F   0.780     0.630   0.215       2.22025          1.4880
# 1417   M   0.705     0.565   0.240       2.21000          1.1075
# ...

# %%
df["Shucked weight"] = df["Shucked weight"].map(lambda x:lowe if x<lowe else uppe if x>uppe else x)

# %%
df[(df["Shucked weight"]<lowe)|(df["Shucked weight"]>uppe)]
# Out:
# Empty DataFrame
# Columns: [Sex, Length, Diameter, Height, Whole weight, Shucked weight, Viscera weight, Shell weight, Rings]
# Index: []

# %%
sns.boxplot(df["Viscera weight"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Viscera weight'>

# %%
sns.distplot(df["Viscera weight"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Viscera weight', ylabel='Density'>

# %%
df["Viscera weight"].skew()
# Out:
# 0.5918521514155083

# %%
df["Viscera weight"].describe()
# Out:
# count    4177.000000
# mean        0.180594
# std         0.109614
# min         0.000500
# 25%         0.093500
# 50%         0.171000
# 75%         0.253000
# max         0.760000
# Name: Viscera weight, dtype: float64

# %%
iqr5=0.253000- 0.093500

# %%
iqr5
# Out:
# 0.1595

# %%
lo=0.093500-(1.5*iqr5)

# %%
lo
# Out:
# -0.14575000000000002

# %%
up=0.253000+(1.5*iqr5)

# %%
up
# Out:
# 0.49225

# %%
df[(df["Viscera weight"]<lo)|(df["Viscera weight"]>up)]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 170    M   0.695     0.550   0.215       1.95650          0.7125
# 1048   M   0.710     0.565   0.205       2.19800          0.9760
# 1052   M   0.765     0.600   0.220       2.22025          0.9760
# 1204   M   0.735     0.585   0.185       2.12400          0.9520
# 1206   F   0.750     0.570   0.210       2.22025          0.9760
# 1207   F   0.755     0.625   0.210       2.22025          0.9760
# 1209   F   0.780     0.630   0.215       2.22025          0.9760
# 1422   M   0.720     0.575   0.215       2.17300          0.9515
# 1427   F   0.750     0.610   0.235       2.22025          0.9760
# 1750   F   0.710     0.570   0.195       1.98050          0.9760
# 1757   F   0.730     0.560   0.190       1.94250          0.7990
# 1759   F   0.740     0.565   0.205       2.11900          0.9655
# 1762   M   0.770     0.620   0.195       2.22025          0.9760
# ...

# %%
df["Viscera weight"] = df["Viscera weight"].map(lambda x:lo if x<lo else up if x>up else x)

# %%
sns.boxplot(df["Shell weight"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Shell weight'>

# %%
sns.distplot(df["Shell weight"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Shell weight', ylabel='Density'>

# %%
df["Shell weight"].skew()
# Out:
# 0.6209268251392077

# %%
df["Shell weight"].describe()
# Out:
# count    4177.000000
# mean        0.238831
# std         0.139203
# min         0.001500
# 25%         0.130000
# 50%         0.234000
# 75%         0.329000
# max         1.005000
# Name: Shell weight, dtype: float64

# %%
iqr6=0.329000-0.130000

# %%
iqr6
# Out:
# 0.199

# %%
li=0.130000-(1.5*iqr5)

# %%
li
# Out:
# -0.10925000000000001

# %%
ui=0.329000+(1.5*iqr5)

# %%
ui
# Out:
# 0.56825

# %%
df[(df["Shell weight"]<li)|(df["Shell weight"]>ui)]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 81     M   0.620     0.510   0.175       1.61500          0.5105
# 83     M   0.595     0.475   0.160       1.31750          0.4080
# 129    M   0.710     0.540   0.165       1.95900          0.7665
# 157    M   0.645     0.485   0.215       1.51400          0.5460
# 163    F   0.725     0.560   0.210       2.14100          0.6500
# ...   ..     ...       ...     ...           ...             ...
# 3928   I   0.725     0.550   0.220       2.04950          0.7735
# 3962   F   0.720     0.575   0.195       2.15050          0.9760
# 3992   M   0.700     0.600   0.230       2.00300          0.8105
# 3993   M   0.720     0.600   0.235       2.22025          0.9760
# 4145   M   0.670     0.525   0.200       1.74050          0.6205
#
#       Viscera weight  Shell weight  Rings
# 81            0.1920        0.6750     12
# 83            0.2340        0.5800     21
# 129           0.2610        0.7800     18
# ...

# %%
df["Shell weight"] = df["Shell weight"].map(lambda x:li if x<li else ui if x>ui else x)

# %%
sns.boxplot(df["Rings"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rings'>

# %%
sns.distplot(df["Rings"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Rings', ylabel='Density'>

# %%
df["Rings"].skew()
# Out:
# 1.114101898355677

# %%
df["Rings"].describe()
# Out:
# count    4177.000000
# mean        9.933684
# std         3.224169
# min         1.000000
# 25%         8.000000
# 50%         9.000000
# 75%        11.000000
# max        29.000000
# Name: Rings, dtype: float64

# %%
iqr7=11.000000-8.000000

# %%
iqr7
# Out:
# 3.0

# %%
lowli=8.000000-(1.5*iqr7)

# %%
lowli
# Out:
# 3.5

# %%
upi=11.000000+(1.5*iqr7)

# %%
upi
# Out:
# 15.5

# %%
df[(df["Rings"]<lowli)|(df["Rings"]>upi)]
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 6      F   0.530     0.415   0.150        0.7775          0.2370
# 7      F   0.545     0.425   0.125        0.7680          0.2940
# 9      F   0.550     0.440   0.150        0.8945          0.3145
# 32     M   0.665     0.525   0.165        1.3380          0.5515
# 33     F   0.680     0.550   0.175        1.7980          0.8150
# ...   ..     ...       ...     ...           ...             ...
# 3929   F   0.650     0.515   0.215        1.4980          0.5640
# 3930   F   0.670     0.535   0.185        1.5970          0.6275
# 3931   I   0.550     0.440   0.165        0.8605          0.3120
# 3944   M   0.550     0.440   0.160        0.9910          0.3480
# 3947   M   0.475     0.365   0.140        0.6175          0.2020
#
#       Viscera weight  Shell weight  Rings
# 6             0.1415         0.330     20
# 7             0.1495         0.260     16
# 9             0.1510         0.320     19
# ...

# %%
df["Rings"] = df["Rings"].map(lambda x:lowli if x<lowli else upi if x>upi else x)

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500   15.0
# 1             0.0485        0.0700    7.0
# 2             0.1415        0.2100    9.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lab=LabelEncoder()

# %%
lab.fit(df["Sex"])
# Out:
# LabelEncoder()

# %%
df["Sex"]=lab.transform(df["Sex"])

# %%
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500   15.0
# 1             0.0485        0.0700    7.0
# 2             0.1415        0.2100    9.0
# ...

# %%
X = df.drop("Sex",axis=1)

# %%
X
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell weight  Rings
# ...

# %%
y=df["Sex"]

# %%
y
# Out:
# 0       2
# 1       2
# 2       0
# 3       2
# 4       1
#        ..
# 4172    0
# 4173    2
# 4174    2
# 4175    0
# 4176    2
# Name: Sex, Length: 4177, dtype: int32

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=2)

# %%
X.shape,X_train.shape,X_test.shape
# Out:
# ((4177, 8), (3341, 8), (836, 8))

# %%
y.shape,y_train.shape,y_test.shape
# Out:
# ((4177,), (3341,), (836,))

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier()

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rfc.score(X_test,y_test)
# Out:
# 0.562200956937799

# %% [markdown]
# # Auto ML

# %%
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier,RandomForestClassifier

# %%
from sklearn.svm import SVC

# %%
from xgboost import XGBRFClassifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
adc=AdaBoostClassifier()

# %%
gbc=GradientBoostingClassifier()

# %%
rfc=RandomForestClassifier()

# %%
svm=SVC()

# %%
xgb=XGBRFClassifier()

# %%
dtc=DecisionTreeClassifier()

# %%
clist=[adc,gbc,rfc,svm,xgb,dtc]

# %%
clist
# Out:
# [AdaBoostClassifier(),
#  GradientBoostingClassifier(),
#  RandomForestClassifier(),
#  SVC(),
#  XGBRFClassifier(base_score=None, booster=None, callbacks=None,
#                  colsample_bylevel=None, colsample_bytree=None,
#                  early_stopping_rounds=None, enable_categorical=False,
#                  eval_metric=None, feature_types=None, gamma=None, gpu_id=None,
#                  grow_policy=None, importance_type=None,
#                  interaction_constraints=None, max_bin=None,
#                  max_cat_threshold=None, max_cat_to_onehot=None,
#                  max_delta_step=None, max_depth=None, max_leaves=None,
#                  min_child_weight=None, missing=nan, monotone_constraints=None,
#                  n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                  objective='binary:logistic', predictor=None, random_state=None,
#                  reg_alpha=None, ...),
#  DecisionTreeClassifier()]

# %%
import time

# %%
for i in clist:
    print(i,end = "==")
    i.fit(X_train,y_train)
    m=i.score(X_test,y_test)
    print(m)
    time.sleep(0.6)
# Out:
# AdaBoostClassifier()==0.5454545454545454
# GradientBoostingClassifier()==0.569377990430622
# RandomForestClassifier()==0.5442583732057417
# SVC()==0.5538277511961722
# XGBRFClassifier(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bytree=None,
#                 early_stopping_rounds=None, enable_categorical=False,
#                 eval_metric=None, feature_types=None, gamma=None, gpu_id=None,
#                 grow_policy=None, importance_type=None,
#                 interaction_constraints=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                 objective='binary:logistic', predictor=None, random_state=None,
# ...

# %% [markdown]
# # K fold cross validation

# %%
from sklearn.model_selection import KFold

# %%
kfold_validation=KFold(10)

# %%
from sklearn.model_selection import cross_val_score

# %%
clist
# Out:
# [AdaBoostClassifier(),
#  GradientBoostingClassifier(),
#  RandomForestClassifier(),
#  SVC(),
#  XGBRFClassifier(base_score=None, booster=None, callbacks=None,
#                  colsample_bylevel=None, colsample_bytree=None,
#                  early_stopping_rounds=None, enable_categorical=False,
#                  eval_metric=None, feature_types=None, gamma=None, gpu_id=None,
#                  grow_policy=None, importance_type=None,
#                  interaction_constraints=None, max_bin=None,
#                  max_cat_threshold=None, max_cat_to_onehot=None,
#                  max_delta_step=None, max_depth=None, max_leaves=None,
#                  min_child_weight=None, missing=nan, monotone_constraints=None,
#                  n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                  objective='multi:softprob', predictor=None, random_state=None,
#                  reg_alpha=None, ...),
#  DecisionTreeClassifier()]

# %%
for mod in clist:
    print(mod,end="==>")
    score=cross_val_score(mod,X,y,cv=kfold_validation)
    print(score)
    print("Average of scores",np.mean(score))
    print("**************************************************************")
# Out:
# AdaBoostClassifier()==>[0.46650718 0.42344498 0.65789474 0.56937799 0.5645933  0.42105263
#  0.6291866  0.51079137 0.58273381 0.57074341]
# Average of scores 0.5396326001399837
# **************************************************************
# GradientBoostingClassifier()==>[0.44976077 0.4354067  0.64832536 0.56937799 0.55263158 0.46889952
#  0.63875598 0.47002398 0.58992806 0.57074341]
# Average of scores 0.5393853338381926
# **************************************************************
# RandomForestClassifier()==>[0.48564593 0.43779904 0.65311005 0.57655502 0.53827751 0.48086124
#  0.64354067 0.48201439 0.59232614 0.53956835]
# Average of scores 0.542969834658589
# **************************************************************
# SVC()==>[0.47368421 0.37799043 0.64832536 0.55263158 0.5645933  0.43062201
#  0.61244019 0.4940048  0.58273381 0.54436451]
# Average of scores 0.5281390198845708
# **************************************************************
# ...

# %% [markdown]
# # stratified kfold cross validation

# %%
from sklearn.model_selection import StratifiedKFold

# %%
skfold_validation=StratifiedKFold(10)

# %%
for mod in clist:
    print(mod,end="==>")
    scores=cross_val_score(mod,X,y,cv=skfold_validation)
    print(scores)
    print("Average of scores",np.mean(scores))
    print("*********************************************************")
# Out:
# AdaBoostClassifier()==>[0.51196172 0.51674641 0.60047847 0.5861244  0.52392344 0.51196172
#  0.59808612 0.53717026 0.54436451 0.52278177]
# Average of scores 0.5453598843413308
# *********************************************************
# GradientBoostingClassifier()==>[0.43779904 0.5215311  0.59808612 0.54545455 0.51435407 0.52631579
#  0.60287081 0.50119904 0.56834532 0.53956835]
# Average of scores 0.5355524193085723
# *********************************************************
# RandomForestClassifier()==>[0.44976077 0.53349282 0.60047847 0.56220096 0.52392344 0.51435407
#  0.61483254 0.48201439 0.57793765 0.52038369]
# Average of scores 0.5379378793615824
# *********************************************************
# SVC()==>[0.42583732 0.51913876 0.55502392 0.56220096 0.50478469 0.5
#  0.58851675 0.53477218 0.55395683 0.5323741 ]
# Average of scores 0.5276605509850494
# *********************************************************
# ...

# %% [markdown]
# # Leave one out cross validation

# %%
from sklearn.model_selection import LeaveOneOut

# %%
Loocv=LeaveOneOut()

# %%
for mod in clist:
    print(mod,end="==>")
    s=cross_val_score(mod,X,y,cv=Loocv)
    print(s)
    print("Average of scores",np.mean(s))
    print("*********************************************************")
# Out:
# AdaBoostClassifier()==>[0. 0. 0. ... 1. 1. 0.]
# Average of scores 0.5712233660521906
# *********************************************************
# GradientBoostingClassifier()==>
