# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
dfmh = pd.read_csv("C:/Users/91970/OneDrive/Documents/Melbourne_housing_FULL (1).csv")

# %%
dfmh
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 0      Abbotsford       68 Studley St      2    h        NaN     SS
# 1      Abbotsford        85 Turner St      2    h  1480000.0      S
# 2      Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3      Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4      Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...           ...                 ...    ...  ...        ...    ...
# 34852  Yarraville         13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville       29A Murray St      2    h   888000.0     SP
# 34854  Yarraville      147A Severn St      2    t   705000.0      S
# 34855  Yarraville    12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville    3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 0             Jellis   3/09/2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
dfmh.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
dfmelbourn=dfmh[["Suburb","Rooms","Type","Method","SellerG","Regionname","Propertycount","Distance","CouncilArea","Bedroom2","Bathroom","Car","Landsize","BuildingArea","Price"]]

# %%
dfmelbourn
# Out:
#            Suburb  Rooms Type Method        SellerG             Regionname  \
# 0      Abbotsford      2    h     SS         Jellis  Northern Metropolitan
# 1      Abbotsford      2    h      S         Biggin  Northern Metropolitan
# 2      Abbotsford      2    h      S         Biggin  Northern Metropolitan
# 3      Abbotsford      3    u     VB         Rounds  Northern Metropolitan
# 4      Abbotsford      3    h     SP         Biggin  Northern Metropolitan
# ...           ...    ...  ...    ...            ...                    ...
# 34852  Yarraville      4    h     PI            Jas   Western Metropolitan
# 34853  Yarraville      2    h     SP        Sweeney   Western Metropolitan
# 34854  Yarraville      2    t      S            Jas   Western Metropolitan
# 34855  Yarraville      3    h     SP  hockingstuart   Western Metropolitan
# 34856  Yarraville      2    h     PI             RW   Western Metropolitan
#
# ...

# %%
dfmelbourn.columns
# Out:
# Index(['Suburb', 'Rooms', 'Type', 'Method', 'SellerG', 'Regionname',
#        'Propertycount', 'Distance', 'CouncilArea', 'Bedroom2', 'Bathroom',
#        'Car', 'Landsize', 'BuildingArea', 'Price'],
#       dtype='object')

# %%
dfmelbourn.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Regionname           3
# Propertycount        3
# Distance             1
# CouncilArea          3
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# Price             7610
# dtype: int64

# %%
dfmelbourn
# Out:
#            Suburb  Rooms Type Method        SellerG             Regionname  \
# 0      Abbotsford      2    h     SS         Jellis  Northern Metropolitan
# 1      Abbotsford      2    h      S         Biggin  Northern Metropolitan
# 2      Abbotsford      2    h      S         Biggin  Northern Metropolitan
# 3      Abbotsford      3    u     VB         Rounds  Northern Metropolitan
# 4      Abbotsford      3    h     SP         Biggin  Northern Metropolitan
# ...           ...    ...  ...    ...            ...                    ...
# 34852  Yarraville      4    h     PI            Jas   Western Metropolitan
# 34853  Yarraville      2    h     SP        Sweeney   Western Metropolitan
# 34854  Yarraville      2    t      S            Jas   Western Metropolitan
# 34855  Yarraville      3    h     SP  hockingstuart   Western Metropolitan
# 34856  Yarraville      2    h     PI             RW   Western Metropolitan
#
# ...

# %%
dfmelbourn[["Propertycount","Distance","Bedroom2","Bathroom","Car"]]
# Out:
#        Propertycount  Distance  Bedroom2  Bathroom  Car
# 0             4019.0       2.5       2.0       1.0  1.0
# 1             4019.0       2.5       2.0       1.0  1.0
# 2             4019.0       2.5       2.0       1.0  0.0
# 3             4019.0       2.5       3.0       2.0  1.0
# 4             4019.0       2.5       3.0       2.0  0.0
# ...              ...       ...       ...       ...  ...
# 34852         6543.0       6.3       4.0       1.0  3.0
# 34853         6543.0       6.3       2.0       2.0  1.0
# 34854         6543.0       6.3       2.0       1.0  2.0
# 34855         6543.0       6.3       NaN       NaN  NaN
# 34856         6543.0       6.3       2.0       1.0  0.0
#
# [34857 rows x 5 columns]

# %%
dfmelbourn[["Propertycount","Distance","Bedroom2","Bathroom","Car"]].isna().sum()
# Out:
# Propertycount       3
# Distance            1
# Bedroom2         8217
# Bathroom         8226
# Car              8728
# dtype: int64

# %%
dfmelbourn[["Propertycount","Distance","Bedroom2","Bathroom","Car"]].fillna(0)
# Out:
#        Propertycount  Distance  Bedroom2  Bathroom  Car
# 0             4019.0       2.5       2.0       1.0  1.0
# 1             4019.0       2.5       2.0       1.0  1.0
# 2             4019.0       2.5       2.0       1.0  0.0
# 3             4019.0       2.5       3.0       2.0  1.0
# 4             4019.0       2.5       3.0       2.0  0.0
# ...              ...       ...       ...       ...  ...
# 34852         6543.0       6.3       4.0       1.0  3.0
# 34853         6543.0       6.3       2.0       2.0  1.0
# 34854         6543.0       6.3       2.0       1.0  2.0
# 34855         6543.0       6.3       0.0       0.0  0.0
# 34856         6543.0       6.3       2.0       1.0  0.0
#
# [34857 rows x 5 columns]

# %%
dfmelbourn[["Propertycount","Distance","Bedroom2","Bathroom","Car"]].fillna(0,inplace=True)
# Out:
# C:\Users\91970\AppData\Local\Temp\ipykernel_23844\3865370969.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmelbourn[["Propertycount","Distance","Bedroom2","Bathroom","Car"]].fillna(0,inplace=True)

# %%
dfmelbourn[["Propertycount","Distance","Bedroom2","Bathroom","Car"]].isna().sum()
# Out:
# Propertycount       3
# Distance            1
# Bedroom2         8217
# Bathroom         8226
# Car              8728
# dtype: int64

# %%
dfmelbourn[["Propertycount","Distance","Bedroom2","Bathroom","Car"]] = dfmelbourn[["Propertycount","Distance","Bedroom2","Bathroom","Car"]].fillna(0)
# Out:
# C:\Users\91970\AppData\Local\Temp\ipykernel_23844\257055850.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmelbourn[["Propertycount","Distance","Bedroom2","Bathroom","Car"]] = dfmelbourn[["Propertycount","Distance","Bedroom2","Bathroom","Car"]].fillna(0)

# %%
dfmelbourn[["Propertycount","Distance","Bedroom2","Bathroom","Car"]].isna().sum()
# Out:
# Propertycount    0
# Distance         0
# Bedroom2         0
# Bathroom         0
# Car              0
# dtype: int64

# %%
dfmelbourn.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Regionname           3
# Propertycount        0
# Distance             0
# CouncilArea          3
# Bedroom2             0
# Bathroom             0
# Car                  0
# Landsize         11810
# BuildingArea     21115
# Price             7610
# dtype: int64

# %%
dfmelbourn["Landsize"].skew()
# Out:
# 96.02231136000024

# %%
sns.boxplot(dfmelbourn["Landsize"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Landsize'>

# %%
q1=dfmelbourn["Landsize"].quantile(0.25)

# %%
q1
# Out:
# 224.0

# %%
q3=dfmelbourn["Landsize"].quantile(0.75)

# %%
q3
# Out:
# 670.0

# %%
iqr=q3-q1

# %%
iqr
# Out:
# 446.0

# %%
lo=q1-(1.5*iqr)

# %%
lo
# Out:
# -445.0

# %%
up=q3+(1.5*iqr)

# %%
up
# Out:
# 1339.0

# %%
dfmelbourn[dfmelbourn["Landsize"]<lo]
# Out:
# Empty DataFrame
# Columns: [Suburb, Rooms, Type, Method, SellerG, Regionname, Propertycount, Distance, CouncilArea, Bedroom2, Bathroom, Car, Landsize, BuildingArea, Price]
# Index: []

# %%
dfmelbourn[dfmelbourn["Landsize"]>up]
# Out:
#               Suburb  Rooms Type Method   SellerG             Regionname  \
# 12        Abbotsford      2    u     PI    Biggin  Northern Metropolitan
# 41        Abbotsford      3    u      S    Jellis  Northern Metropolitan
# 388         Armadale      4    h     VB    Jellis  Southern Metropolitan
# 392         Armadale      3    u     PI  Marshall  Southern Metropolitan
# 426         Armadale      6    h      S  Marshall  Southern Metropolitan
# ...              ...    ...  ...    ...       ...                    ...
# 34055   Bullengarook      4    h      S     Raine      Northern Victoria
# 34186        Donvale      5    h      S       Ray   Eastern Metropolitan
# 34367       Hillside      6    h     PI     Barry   Western Metropolitan
# 34477   Melton South      3    h      S     Barry       Western Victoria
# 34485  Menzies Creek      4    h     SS      Kaye       Eastern Victoria
#
#        Propertycount  Distance                   CouncilArea  Bedroom2  \
# ...

# %%
dfmelbourn["Landsize"].map(lambda x :lo if x<lo else up if x>up else x)
# Out:
# 0        126.0
# 1        202.0
# 2        156.0
# 3          0.0
# 4        134.0
#          ...
# 34852    593.0
# 34853     98.0
# 34854    220.0
# 34855      NaN
# 34856    250.0
# Name: Landsize, Length: 34857, dtype: float64

# %%
dfmelbourn["Landsize"] = dfmelbourn["Landsize"].map(lambda x :lo if x<lo else up if x>up else x)
# Out:
# C:\Users\91970\AppData\Local\Temp\ipykernel_23844\1440892289.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmelbourn["Landsize"] = dfmelbourn["Landsize"].map(lambda x :lo if x<lo else up if x>up else x)

# %%
dfmelbourn[dfmelbourn["Landsize"]>up]
# Out:
# Empty DataFrame
# Columns: [Suburb, Rooms, Type, Method, SellerG, Regionname, Propertycount, Distance, CouncilArea, Bedroom2, Bathroom, Car, Landsize, BuildingArea, Price]
# Index: []

# %%
dfmelbourn
# Out:
#            Suburb  Rooms Type Method        SellerG             Regionname  \
# 0      Abbotsford      2    h     SS         Jellis  Northern Metropolitan
# 1      Abbotsford      2    h      S         Biggin  Northern Metropolitan
# 2      Abbotsford      2    h      S         Biggin  Northern Metropolitan
# 3      Abbotsford      3    u     VB         Rounds  Northern Metropolitan
# 4      Abbotsford      3    h     SP         Biggin  Northern Metropolitan
# ...           ...    ...  ...    ...            ...                    ...
# 34852  Yarraville      4    h     PI            Jas   Western Metropolitan
# 34853  Yarraville      2    h     SP        Sweeney   Western Metropolitan
# 34854  Yarraville      2    t      S            Jas   Western Metropolitan
# 34855  Yarraville      3    h     SP  hockingstuart   Western Metropolitan
# 34856  Yarraville      2    h     PI             RW   Western Metropolitan
#
# ...

# %%
dfmelbourn["BuildingArea"].skew()
# Out:
# 99.13257936713703

# %%
sns.displot(dfmelbourn["BuildingArea"],bins=20)

# %%
sns.boxplot(dfmelbourn["BuildingArea"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='BuildingArea'>

# %%
qu1=dfmelbourn["BuildingArea"].quantile(0.25)

# %%
qu1
# Out:
# 102.0

# %%
qu3=dfmelbourn["BuildingArea"].quantile(0.75)

# %%
qu3
# Out:
# 188.0

# %%
iqr=q3-q1

# %%
iqr
# Out:
# 446.0

# %%
lower=qu1-(1.5*iqr)

# %%
lower
# Out:
# -567.0

# %%
upper=qu3+(1.5*iqr)

# %%
upper
# Out:
# 857.0

# %%
dfmelbourn[dfmelbourn["BuildingArea"]<lower]
# Out:
# Empty DataFrame
# Columns: [Suburb, Rooms, Type, Method, SellerG, Regionname, Propertycount, Distance, CouncilArea, Bedroom2, Bathroom, Car, Landsize, BuildingArea, Price]
# Index: []

# %%
dfmelbourn[dfmelbourn["BuildingArea"]>upper]
# Out:
#                 Suburb  Rooms Type Method        SellerG  \
# 1639          Box Hill      5    h      S           Noel
# 2296         Brunswick      3    h      S            Ray
# 2466           Bulleen      4    h      S          Barry
# 2704        Camberwell      5    h      S       Marshall
# 3780       Elsternwick      2    u      S         Biggin
# 4256     Fitzroy North      2    t      S         Nelson
# 4681         Glen Iris      2    t     VB           Gary
# 5992               Kew      5    h      S            Kay
# 14387  Frankston South      3    h     SP  hockingstuart
# 15003    Glen Waverley      5    h     PI            Ray
# 19537            Lalor      3    h      S           Love
# 22213  Bayswater North      4    h      S        McGrath
# 22531       Kensington      1    u      S         Edward
# 22632     New Gisborne      5    h      S          Raine
# 23110           Elwood      3    h      S             RT
# ...

# %%
dfmelbourn["BuildingArea"].map(lambda x :lower if x<lower else upper if x>upper else x)
# Out:
# 2         79.0
# 4        150.0
# 6        142.0
# 11       210.0
# 14       107.0
#          ...
# 34847    118.0
# 34849    158.0
# 34853    104.0
# 34854    120.0
# 34856    103.0
# Name: BuildingArea, Length: 9382, dtype: float64

# %%
dfmelbourn.dropna()
# Out:
#            Suburb  Rooms Type Method  SellerG             Regionname  \
# 2      Abbotsford      2    h      S   Biggin  Northern Metropolitan
# 4      Abbotsford      3    h     SP   Biggin  Northern Metropolitan
# 6      Abbotsford      4    h     VB   Nelson  Northern Metropolitan
# 11     Abbotsford      3    h      S   Nelson  Northern Metropolitan
# 14     Abbotsford      2    h      S   Nelson  Northern Metropolitan
# ...           ...    ...  ...    ...      ...                    ...
# 34847     Wollert      3    h     PI      Ray  Northern Metropolitan
# 34849     Wollert      3    h     SP       RW  Northern Metropolitan
# 34853  Yarraville      2    h     SP  Sweeney   Western Metropolitan
# 34854  Yarraville      2    t      S      Jas   Western Metropolitan
# 34856  Yarraville      2    h     PI       RW   Western Metropolitan
#
#        Propertycount  Distance               CouncilArea  Bedroom2  Bathroom  \
# ...

# %%
dfmelbourn.dropna().isna().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Regionname       0
# Propertycount    0
# Distance         0
# CouncilArea      0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# Price            0
# dtype: int64

# %%
dfmelbourn.dropna(inplace=True)
# Out:
# C:\Users\91970\AppData\Local\Temp\ipykernel_23844\43547477.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmelbourn.dropna(inplace=True)

# %%
dfmelbourn["BuildingArea"] = dfmelbourn["BuildingArea"].map(lambda x :lower if x<lower else upper if x>upper else x)
# Out:
# C:\Users\91970\AppData\Local\Temp\ipykernel_23844\787544687.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmelbourn["BuildingArea"] = dfmelbourn["BuildingArea"].map(lambda x :lower if x<lower else upper if x>upper else x)

# %%
dfmelbourn
# Out:
#            Suburb  Rooms Type Method  SellerG             Regionname  \
# 2      Abbotsford      2    h      S   Biggin  Northern Metropolitan
# 4      Abbotsford      3    h     SP   Biggin  Northern Metropolitan
# 6      Abbotsford      4    h     VB   Nelson  Northern Metropolitan
# 11     Abbotsford      3    h      S   Nelson  Northern Metropolitan
# 14     Abbotsford      2    h      S   Nelson  Northern Metropolitan
# ...           ...    ...  ...    ...      ...                    ...
# 34847     Wollert      3    h     PI      Ray  Northern Metropolitan
# 34849     Wollert      3    h     SP       RW  Northern Metropolitan
# 34853  Yarraville      2    h     SP  Sweeney   Western Metropolitan
# 34854  Yarraville      2    t      S      Jas   Western Metropolitan
# 34856  Yarraville      2    h     PI       RW   Western Metropolitan
#
#        Propertycount  Distance               CouncilArea  Bedroom2  Bathroom  \
# ...

# %%
pd.get_dummies(dfmelbourn)
# Out:
#        Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 2          2         4019.0       2.5       2.0       1.0  0.0     156.0
# 4          3         4019.0       2.5       3.0       2.0  0.0     134.0
# 6          4         4019.0       2.5       3.0       1.0  2.0     120.0
# 11         3         4019.0       2.5       4.0       2.0  0.0     245.0
# 14         2         4019.0       2.5       2.0       1.0  2.0     256.0
# ...      ...            ...       ...       ...       ...  ...       ...
# 34847      3         2940.0      25.5       3.0       2.0  2.0     383.0
# 34849      3         2940.0      25.5       3.0       2.0  2.0     404.0
# 34853      2         6543.0       6.3       2.0       2.0  1.0      98.0
# 34854      2         6543.0       6.3       2.0       1.0  2.0     220.0
# 34856      2         6543.0       6.3       2.0       1.0  0.0     250.0
#
#        BuildingArea      Price  Suburb_Abbotsford  ...  \
# ...

# %%
pd.get_dummies(dfmelbourn,drop_first=True)
# Out:
#        Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 2          2         4019.0       2.5       2.0       1.0  0.0     156.0
# 4          3         4019.0       2.5       3.0       2.0  0.0     134.0
# 6          4         4019.0       2.5       3.0       1.0  2.0     120.0
# 11         3         4019.0       2.5       4.0       2.0  0.0     245.0
# 14         2         4019.0       2.5       2.0       1.0  2.0     256.0
# ...      ...            ...       ...       ...       ...  ...       ...
# 34847      3         2940.0      25.5       3.0       2.0  2.0     383.0
# 34849      3         2940.0      25.5       3.0       2.0  2.0     404.0
# 34853      2         6543.0       6.3       2.0       2.0  1.0      98.0
# 34854      2         6543.0       6.3       2.0       1.0  2.0     220.0
# 34856      2         6543.0       6.3       2.0       1.0  0.0     250.0
#
#        BuildingArea      Price  Suburb_Aberfeldie  ...  \
# ...

# %%
dfmelbourn=pd.get_dummies(dfmelbourn,drop_first=True)

# %%
dfmelbourn
# Out:
#        Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 2          2         4019.0       2.5       2.0       1.0  0.0     156.0
# 4          3         4019.0       2.5       3.0       2.0  0.0     134.0
# 6          4         4019.0       2.5       3.0       1.0  2.0     120.0
# 11         3         4019.0       2.5       4.0       2.0  0.0     245.0
# 14         2         4019.0       2.5       2.0       1.0  2.0     256.0
# ...      ...            ...       ...       ...       ...  ...       ...
# 34847      3         2940.0      25.5       3.0       2.0  2.0     383.0
# 34849      3         2940.0      25.5       3.0       2.0  2.0     404.0
# 34853      2         6543.0       6.3       2.0       2.0  1.0      98.0
# 34854      2         6543.0       6.3       2.0       1.0  2.0     220.0
# 34856      2         6543.0       6.3       2.0       1.0  0.0     250.0
#
#        BuildingArea      Price  Suburb_Aberfeldie  ...  \
# ...

# %%
dfmelbourn.dtypes
# Out:
# Rooms                                       int64
# Propertycount                             float64
# Distance                                  float64
# Bedroom2                                  float64
# Bathroom                                  float64
#                                            ...
# CouncilArea_Whitehorse City Council         uint8
# CouncilArea_Whittlesea City Council         uint8
# CouncilArea_Wyndham City Council            uint8
# CouncilArea_Yarra City Council              uint8
# CouncilArea_Yarra Ranges Shire Council      uint8
# Length: 626, dtype: object

# %%
x=dfmelbourn.drop("Price",axis=1)

# %%
x
# Out:
#        Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 2          2         4019.0       2.5       2.0       1.0  0.0     156.0
# 4          3         4019.0       2.5       3.0       2.0  0.0     134.0
# 6          4         4019.0       2.5       3.0       1.0  2.0     120.0
# 11         3         4019.0       2.5       4.0       2.0  0.0     245.0
# 14         2         4019.0       2.5       2.0       1.0  2.0     256.0
# ...      ...            ...       ...       ...       ...  ...       ...
# 34847      3         2940.0      25.5       3.0       2.0  2.0     383.0
# 34849      3         2940.0      25.5       3.0       2.0  2.0     404.0
# 34853      2         6543.0       6.3       2.0       2.0  1.0      98.0
# 34854      2         6543.0       6.3       2.0       1.0  2.0     220.0
# 34856      2         6543.0       6.3       2.0       1.0  0.0     250.0
#
#        BuildingArea  Suburb_Aberfeldie  Suburb_Airport West  ...  \
# ...

# %%
y=dfmelbourn["Price"]

# %%
y
# Out:
# 2        1035000.0
# 4        1465000.0
# 6        1600000.0
# 11       1876000.0
# 14       1636000.0
#            ...
# 34847     500000.0
# 34849     570000.0
# 34853     888000.0
# 34854     705000.0
# 34856    1020000.0
# Name: Price, Length: 9382, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=2)

# %%
x.shape,x_train.shape,x_test.shape
# Out:
# ((9382, 625), (7505, 625), (1877, 625))

# %%
y.shape,y_train.shape,y_test.shape
# Out:
# ((9382,), (7505,), (1877,))

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor

# %%
from xgboost import XGBRFRegressor

# %%
from sklearn.svm import SVR

# %%
dtr=DecisionTreeRegressor()

# %%
lreg=LinearRegression()

# %%
rfr=RandomForestRegressor()

# %%
abr=AdaBoostRegressor()

# %%
gbr=GradientBoostingRegressor()

# %%
xgb=XGBRFRegressor()

# %%
svm=SVR()

# %%
clist=[dtr,lreg,rfr,abr,gbr,xgb,svm]

# %%
clist
# Out:
# [DecisionTreeRegressor(),
#  LinearRegression(),
#  RandomForestRegressor(),
#  AdaBoostRegressor(),
#  GradientBoostingRegressor(),
#  XGBRFRegressor(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=None, colsample_bytree=None,
#                 early_stopping_rounds=None, enable_categorical=False,
#                 eval_metric=None, feature_types=None, gamma=None, gpu_id=None,
#                 grow_policy=None, importance_type=None,
#                 interaction_constraints=None, max_bin=None,
#                 max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=None, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                 objective='reg:squarederror', predictor=None, random_state=None,
#                 reg_alpha=None, ...),
#  SVR()]

# %%
import time

# %%
for i in clist:
    print(i,end = "==")
    i.fit(x_train,y_train)
    m=i.score(x_test,y_test)
    print(m)
    time.sleep(0.6)
# Out:
# DecisionTreeRegressor()==0.5078720298485089
# LinearRegression()==0.6989964845696051
# RandomForestRegressor()==0.7858276502734929
# AdaBoostRegressor()==-0.20115584956512533
# GradientBoostingRegressor()==0.7656547043203282
# XGBRFRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bytree=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric=None, feature_types=None, gamma=None, gpu_id=None,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                n_estimators=100, n_jobs=None, num_parallel_tree=None,
#                objective='reg:squarederror', predictor=None, random_state=None,
# ...

# %%
rlist=[]
for i in range(0,51):
    print("random_state=",i)
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    for m in clist:
        print(m,end = "==")
        m.fit(x_train,y_train)
        s=m.score(x_test,y_test)
        print(s)
        rlist.append(s)
        print("********************************************************************************")
        print("Max = ",max(rlist))
        rlist.index(max(rlist))
        print("Max_index =",rlist.index(max(rlist)))
        print("*********************************************************************************")
# Out:
# random_state= 0
# DecisionTreeRegressor()==0.6609954423674964
# ********************************************************************************
# Max =  0.6609954423674964
# Max_index = 0
# *********************************************************************************
# LinearRegression()==0.6736002530371727
# ********************************************************************************
# Max =  0.6736002530371727
# Max_index = 1
# *********************************************************************************
# RandomForestRegressor()==0.8250972070187546
# ********************************************************************************
# Max =  0.8250972070187546
# Max_index = 2
# *********************************************************************************
# AdaBoostRegressor()==0.051084926334454384
# ********************************************************************************
# Max =  0.8250972070187546
# Max_index = 2
# ...
