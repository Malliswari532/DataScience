# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/91970/OneDrive/Documents/winequality-red.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
sns.boxplot(df["sulphates"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='sulphates'>

# %%
df["sulphates"].skew()
# Out:
# 2.4286723536602945

# %%
sns.displot(df["sulphates"])

# %%
sns.distplot(df["sulphates"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sulphates', ylabel='Density'>

# %% [markdown]
# # Error datection by applying IQR

# %%
q1=df["sulphates"].quantile(0.25)

# %%
q1
# Out:
# 0.55

# %%
q3 = df["sulphates"].quantile(0.75)

# %%
q3
# Out:
# 0.73

# %%
iqr=q3-q1

# %%
iqr
# Out:
# 0.17999999999999994

# %%
lower=q1-(1.5*iqr)

# %%
lower
# Out:
# 0.28000000000000014

# %%
upper=q3+(1.5*iqr)

# %%
upper
# Out:
# 0.9999999999999999

# %%
df[df["sulphates"]<lower]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %%
df[df["sulphates"]>upper]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 13              7.8             0.610         0.29             1.6      0.114
# 17              8.1             0.560         0.28             1.7      0.368
# 19              7.9             0.320         0.51             1.8      0.341
# 43              8.1             0.660         0.22             2.2      0.069
# 79              8.3             0.625         0.20             1.5      0.080
# 81              7.8             0.430         0.70             1.9      0.464
# 83              7.3             0.670         0.26             1.8      0.401
# 86              8.6             0.490         0.28             1.9      0.110
# 88              9.3             0.390         0.44             2.1      0.107
# 91              8.6             0.490         0.28             1.9      0.110
# 92              8.6             0.490         0.29             2.0      0.110
# ...

# %%
df["sulphates"].map(lambda x :lower if x<lower else upper if x>upper else x)
# Out:
# 0       0.56
# 1       0.68
# 2       0.65
# 3       0.58
# 4       0.56
#         ...
# 1594    0.58
# 1595    0.76
# 1596    0.75
# 1597    0.71
# 1598    0.66
# Name: sulphates, Length: 1599, dtype: float64

# %%
df["sulphates"] = df["sulphates"].map(lambda x :lower if x<lower else upper if x>upper else x)

# %%
sns.boxplot(df["fixed acidity"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='fixed acidity'>

# %% [markdown]
# # Error detection by applying IQR

# %%
qu1=df["fixed acidity"].quantile(0.25)

# %%
qu1
# Out:
# 7.1

# %%
qu3 = df["fixed acidity"].quantile(0.75)

# %%
qu3
# Out:
# 9.2

# %%
iqr1=qu3-qu1

# %%
iqr1
# Out:
# 2.0999999999999996

# %%
lower1=qu1-(1.5*iqr1)

# %%
lower1
# Out:
# 3.95

# %%
upper1=qu3+(1.5*iqr1)

# %%
upper1
# Out:
# 12.349999999999998

# %%
df[df["fixed acidity"]<lower1]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %%
df[df["fixed acidity"]>upper1]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 205            12.8             0.300         0.74             2.6      0.095
# 206            12.8             0.300         0.74             2.6      0.095
# 243            15.0             0.210         0.44             2.2      0.075
# 244            15.0             0.210         0.44             2.2      0.075
# 264            12.5             0.560         0.49             2.4      0.064
# 294            13.3             0.340         0.52             3.2      0.094
# 328            13.4             0.270         0.62             2.6      0.082
# 338            12.4             0.490         0.58             3.0      0.103
# 339            12.5             0.280         0.54             2.3      0.082
# 347            13.8             0.490         0.67             3.0      0.093
# 353            13.5             0.530         0.79             4.8      0.120
# ...

# %%
df["fixed acidity"].map(lambda x :lower1 if x<lower1 else upper1 if x>upper1 else x)
# Out:
# 0        7.4
# 1        7.8
# 2        7.8
# 3       11.2
# 4        7.4
#         ...
# 1594     6.2
# 1595     5.9
# 1596     6.3
# 1597     5.9
# 1598     6.0
# Name: fixed acidity, Length: 1599, dtype: float64

# %%
df["fixed acidity"] = df["fixed acidity"].map(lambda x :lower1 if x<lower1 else upper1 if x>upper1 else x)

# %%
sns.boxplot(df["volatile acidity"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='volatile acidity'>

# %%
df["volatile acidity"].skew()
# Out:
# 0.6715925723840199

# %% [markdown]
# # Error datection by applying IQR

# %%
qua1=df["volatile acidity"].quantile(0.25)

# %%
qua1
# Out:
# 0.39

# %%
qua3=df["volatile acidity"].quantile(0.75)

# %%
qua3
# Out:
# 0.64

# %%
iqr2=qua3-qua1

# %%
iqr2
# Out:
# 0.25

# %%
lower2 = qua1-(1.5*iqr2)

# %%
lower2
# Out:
# 0.015000000000000013

# %%
upper2=qua3+(1.5*iqr2)

# %%
upper2
# Out:
# 1.0150000000000001

# %%
df[df["volatile acidity"]<lower2]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %%
df[df["volatile acidity"]>upper2]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 38              5.7             1.130         0.09            1.50      0.172
# 94              5.0             1.020         0.04            1.40      0.045
# 120             7.3             1.070         0.09            1.70      0.178
# 126             8.2             1.330         0.00            1.70      0.081
# 127             8.1             1.330         0.00            1.80      0.082
# 134             7.9             1.040         0.05            2.20      0.084
# 199             6.9             1.090         0.06            2.10      0.061
# 553             5.0             1.040         0.24            1.60      0.050
# 672             9.8             1.240         0.34            2.00      0.079
# 690             7.4             1.185         0.00            4.25      0.097
# 700            10.6             1.020         0.43            2.90      0.076
# ...

# %%
df["volatile acidity"].map(lambda x :lower2 if x<lower2 else upper2 if x>upper2 else x)
# Out:
# 0       0.700
# 1       0.880
# 2       0.760
# 3       0.280
# 4       0.700
#         ...
# 1594    0.600
# 1595    0.550
# 1596    0.510
# 1597    0.645
# 1598    0.310
# Name: volatile acidity, Length: 1599, dtype: float64

# %%
df["volatile acidity"] = df["volatile acidity"].map(lambda x :lower2 if x<lower2 else upper2 if x>upper2 else x)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
sns.boxplot(df["citric acid"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='citric acid'>

# %%
sns.distplot(df["citric acid"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='citric acid', ylabel='Density'>

# %%
df["citric acid"].skew()
# Out:
# 0.3183372952546368

# %% [markdown]
# # Error detection by applying mean-std

# %%
a=df["citric acid"].mean()

# %%
a
# Out:
# 0.2709756097560964

# %%
s=df["citric acid"].std()

# %%
s
# Out:
# 0.19480113740531785

# %%
lower3 = a-3*s

# %%
lower3
# Out:
# -0.3134278024598572

# %%
upper3=a+3*s

# %%
upper3
# Out:
# 0.8553790219720501

# %%
df[df["citric acid"]<lower3]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %%
df[df["citric acid"]>upper3]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 151            9.2              0.52          1.0             3.4       0.61
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 151                 32.0                  69.0   0.9996  2.74        1.0
#
#      alcohol  quality
# 151      9.4        4

# %%
df["citric acid"].map(lambda x :lower3 if x<lower3 else upper3 if x>upper3 else x)
# Out:
# 0       0.00
# 1       0.00
# 2       0.04
# 3       0.56
# 4       0.00
#         ...
# 1594    0.08
# 1595    0.10
# 1596    0.13
# 1597    0.12
# 1598    0.47
# Name: citric acid, Length: 1599, dtype: float64

# %%
df["citric acid"] = df["citric acid"].map(lambda x :lower3 if x<lower3 else upper3 if x>upper3 else x)

# %%
sns.displot(df["residual sugar"])

# %% [markdown]
# # Error detection by applying IQR

# %%
rsq1=df["residual sugar"].quantile(0.25)

# %%
rsq1
# Out:
# 1.9

# %%
rsq3=df["residual sugar"].quantile(0.75)

# %%
rsq3
# Out:
# 2.6

# %%
iqr3=rsq3-rsq1

# %%
iqr3
# Out:
# 0.7000000000000002

# %%
lower4 =rsq1-(1.5*iqr3)

# %%
lower4
# Out:
# 0.8499999999999996

# %%
upper4 = rsq3+(1.5*iqr3)

# %%
upper4
# Out:
# 3.6500000000000004

# %%
df[df["residual sugar"]<lower4]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %%
df[df["residual sugar"]>upper4]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 9               7.5             0.500         0.36             6.1      0.071
# 11              7.5             0.500         0.36             6.1      0.071
# 14              8.9             0.620         0.18             3.8      0.176
# 15              8.9             0.620         0.19             3.9      0.170
# 18              7.4             0.590         0.08             4.4      0.086
# ...             ...               ...          ...             ...        ...
# 1552            6.3             0.680         0.01             3.7      0.103
# 1558            6.9             0.630         0.33             6.7      0.235
# 1574            5.6             0.310         0.78            13.9      0.074
# 1577            6.2             0.700         0.15             5.1      0.076
# 1589            6.6             0.725         0.20             7.8      0.073
#
# ...

# %%
 df["residual sugar"].map(lambda x :lower4 if x<lower4 else upper4 if x>upper4 else x)
# Out:
# 0       1.9
# 1       2.6
# 2       2.3
# 3       1.9
# 4       1.9
#        ...
# 1594    2.0
# 1595    2.2
# 1596    2.3
# 1597    2.0
# 1598    3.6
# Name: residual sugar, Length: 1599, dtype: float64

# %%
df["residual sugar"] = df["residual sugar"].map(lambda x :lower4 if x<lower4 else upper4 if x>upper4 else x)

# %%
sns.boxplot(df["chlorides"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='chlorides'>

# %%
sns.distplot(df["chlorides"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='chlorides', ylabel='Density'>

# %%
df["chlorides"].skew()
# Out:
# 5.680346571971722

# %% [markdown]
# # Error detection by applying percentile

# %%
lower5 = df["chlorides"].quantile(0.05)
upper5=df["chlorides"].quantile(0.95)
lower5,upper5
# Out:
# (0.054, 0.1260999999999999)

# %%
df[df["chlorides"]<lower5]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 44              6.8             0.670         0.02             1.8      0.050
# 94              5.0             1.015         0.04             1.4      0.045
# 131             5.6             0.500         0.09             2.3      0.049
# 132             5.6             0.500         0.09             2.3      0.049
# 142             5.2             0.340         0.00             1.8      0.050
# ...             ...               ...          ...             ...        ...
# 1547            6.3             0.600         0.10             1.6      0.048
# 1571            6.4             0.380         0.14             2.2      0.038
# 1579            6.2             0.560         0.09             1.7      0.053
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
#
# ...

# %%
df[df["chlorides"]>upper5]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 14              8.9             0.620         0.18            3.65      0.176
# 15              8.9             0.620         0.19            3.65      0.170
# 17              8.1             0.560         0.28            1.70      0.368
# 19              7.9             0.320         0.51            1.80      0.341
# 38              5.7             1.015         0.09            1.50      0.172
# ...             ...               ...          ...             ...        ...
# 1436           10.0             0.380         0.38            1.60      0.169
# 1474            9.9             0.500         0.50            3.65      0.205
# 1476            9.9             0.500         0.50            3.65      0.205
# 1558            6.9             0.630         0.33            3.65      0.235
# 1570            6.4             0.360         0.53            2.20      0.230
#
# ...

# %%
df["chlorides"] = df["chlorides"].map(lambda x :lower5 if x<lower5 else upper5 if x>upper5 else x)

# %%
sns.boxplot(df["free sulfur dioxide"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='free sulfur dioxide'>

# %%
sns.distplot(df["free sulfur dioxide"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='Density'>

# %%
df["free sulfur dioxide"].skew()
# Out:
# 1.250567293314441

# %% [markdown]
# # Error detection by applying IQR

# %%
fsq1=df["free sulfur dioxide"].quantile(0.25)

# %%
fsq1
# Out:
# 7.0

# %%
fsq3=df["free sulfur dioxide"].quantile(0.75)

# %%
fsq3
# Out:
# 21.0

# %%
fsiqr=fsq3-fsq1

# %%
fsiqr
# Out:
# 14.0

# %%
fslow=fsq1-(1.5*fsiqr)

# %%
fslow
# Out:
# -14.0

# %%
fsup=fsq3+(1.5*fsiqr)

# %%
df[df["free sulfur dioxide"]<fslow]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %%
df[df["free sulfur dioxide"]<fsup]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df["free sulfur dioxide"].map(lambda x :fslow if x<fslow else fsup if x>fsup else x )
# Out:
# 0       11.0
# 1       25.0
# 2       15.0
# 3       17.0
# 4       11.0
#         ...
# 1594    32.0
# 1595    39.0
# 1596    29.0
# 1597    32.0
# 1598    18.0
# Name: free sulfur dioxide, Length: 1599, dtype: float64

# %%
df["free sulfur dioxide"] = df["free sulfur dioxide"].map(lambda x :fslow if x<fslow else fsup if x>fsup else x )

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df["total sulfur dioxide"].plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
sns.distplot(df["total sulfur dioxide"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='Density'>

# %%
df["total sulfur dioxide"].skew()
# Out:
# 1.515531257594554

# %% [markdown]
# # Error detection by applying IQR

# %%
tsdq1=df["total sulfur dioxide"].quantile(0.25)

# %%
tsdq1
# Out:
# 22.0

# %%
tsdq3=df["total sulfur dioxide"].quantile(0.75)

# %%
tsdq3
# Out:
# 62.0

# %%
tsdiqr=tsdq3-tsdq1

# %%
tsdiqr
# Out:
# 40.0

# %%
tsdlow=tsdq1-(1.5*tsdiqr)

# %%
tsdlow
# Out:
# -38.0

# %%
tsdup=tsdq3+(1.5*tsdiqr)

# %%
tsdup
# Out:
# 122.0

# %%
df[df["total sulfur dioxide"]<tsdlow]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %%
df[df["total sulfur dioxide"]<tsdup]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df["total sulfur dioxide"].map(lambda x :tsdlow if x<tsdlow else tsdup if x>tsdup else x)
# Out:
# 0       34.0
# 1       67.0
# 2       54.0
# 3       60.0
# 4       34.0
#         ...
# 1594    44.0
# 1595    51.0
# 1596    40.0
# 1597    44.0
# 1598    42.0
# Name: total sulfur dioxide, Length: 1599, dtype: float64

# %%
df["total sulfur dioxide"]=df["total sulfur dioxide"].map(lambda x :tsdlow if x<tsdlow else tsdup if x>tsdup else x)

# %%
sns.distplot(df["density"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='density', ylabel='Density'>

# %%
df["density"].skew()
# Out:
# 0.07128766294927483

# %% [markdown]
# # Error detection by applying mean-std

# %%
dm=df["density"].mean()

# %%
ds=df["density"].std()

# %%
dlow = dm-3*ds

# %%
dlow
# Out:
# 0.9910846773129555

# %%
dup=dm+3*ds

# %%
dup
# Out:
# 1.0024086810360109

# %%
df[df["density"]<dlow]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 836             6.7              0.28         0.28            2.40      0.054
# 837             6.7              0.28         0.28            2.40      0.054
# 1017            8.0              0.18         0.37            0.90      0.054
# 1018            8.0              0.18         0.37            0.90      0.054
# 1114            5.0              0.40         0.50            3.65      0.054
# 1269            5.5              0.49         0.03            1.80      0.054
# 1270            5.0              0.38         0.01            1.60      0.054
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 836                  36.0                 100.0  0.99064  3.26       0.39
# 837                  36.0                 100.0  0.99064  3.26       0.39
# 1017                 36.0                 109.0  0.99007  2.89       0.44
# ...

# %%
df[df["density"]<dup]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df["density"] = df["density"].map(lambda x :dlow if x<dlow else dup if x>dup else x)

# %%
sns.distplot(df["pH"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='pH', ylabel='Density'>

# %%
df["pH"].skew()
# Out:
# 0.19368349811284427

# %% [markdown]
# # Error detection by applying mean-std

# %%
phm=df["pH"].mean()

# %%
phm
# Out:
# 3.311113195747343

# %%
phs=df["pH"].std()

# %%
phs
# Out:
# 0.15438646490354266

# %%
plow = phm-3*phs

# %%
plow
# Out:
# 2.847953801036715

# %%
pup = phm+3*phs

# %%
pup
# Out:
# 3.774272590457971

# %%
df[df["pH"]<plow]
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 151            9.2              0.52     0.855379             3.4     0.1261
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 151                 32.0                  69.0   0.9996  2.74        1.0
#
#      alcohol  quality
# 151      9.4        4

# %%
df[df["pH"]>pup]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 45              4.6             0.520         0.15            2.10      0.054
# 95              4.7             0.600         0.17            2.30      0.058
# 695             5.1             0.470         0.02            1.30      0.054
# 1111            5.4             0.420         0.27            2.00      0.092
# 1300            5.2             0.645         0.00            2.15      0.080
# 1316            5.4             0.740         0.00            1.20      0.054
# 1321            5.0             0.740         0.00            1.20      0.054
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 45                    8.0                  65.0  0.99340  3.90       0.56
# 95                   17.0                 106.0  0.99320  3.85       0.60
# 695                  18.0                  44.0  0.99210  3.90       0.62
# ...

# %%
df["pH"] =  df["pH"].map(lambda x :plow if x<plow else pup if x>pup else x)

# %%
sns.distplot(df["alcohol"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %%
df["alcohol"].skew()
# Out:
# 0.8608288068888538

# %% [markdown]
# # Error detection by applying IQR

# %%
aq1=df["alcohol"].quantile(0.25)

# %%
aq1
# Out:
# 9.5

# %%
aq3=df["alcohol"].quantile(0.75)

# %%
aq3
# Out:
# 11.1

# %%
aiqr = aq3-aq1

# %%
aiqr
# Out:
# 1.5999999999999996

# %%
alow=aq1-1.5*aiqr

# %%
alow
# Out:
# 7.1000000000000005

# %%
aup=aq3+1.5*aiqr

# %%
aup
# Out:
# 13.5

# %%
df[df["alcohol"]<alow]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %%
df[df["alcohol"]<aup]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df["alcohol"].map(lambda x :alow if x<alow else aup if x>aup else x)
# Out:
# 0        9.4
# 1        9.8
# 2        9.8
# 3        9.8
# 4        9.4
#         ...
# 1594    10.5
# 1595    11.2
# 1596    11.0
# 1597    10.2
# 1598    11.0
# Name: alcohol, Length: 1599, dtype: float64

# %%
df["alcohol"] = df["alcohol"].map(lambda x :alow if x<alow else aup if x>aup else x)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
sns.distplot(df["quality"])
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='quality', ylabel='Density'>

# %%
df["quality"].skew()
# Out:
# 0.21780157547366327

# %% [markdown]
# # Error detection by applying mean-std

# %%
qm=df["quality"].mean()

# %%
qm
# Out:
# 5.6360225140712945

# %%
qs=df["quality"].std()

# %%
qs
# Out:
# 0.8075694397347023

# %%
qlow=qm-3*qs

# %%
qlow
# Out:
# 3.2133141948671877

# %%
qup=qm+3*qs

# %%
qup
# Out:
# 8.058730833275401

# %%
df[df["quality"]<qlow]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 459            11.6             0.580         0.66            2.20     0.0740
# 517            10.4             0.610         0.49            2.10     0.1261
# 690             7.4             1.015         0.00            3.65     0.0970
# 832            10.4             0.440         0.42            1.50     0.1261
# 899             8.3             1.015         0.02            3.40     0.0840
# 1299            7.6             1.015         0.00            2.10     0.1261
# 1374            6.8             0.815         0.00            1.20     0.1261
# 1469            7.3             0.980         0.05            2.10     0.0610
# 1478            7.1             0.875         0.05            3.65     0.0820
# 1505            6.7             0.760         0.02            1.80     0.0780
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df[df["quality"]>qup]
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %%
from scipy.stats import zscore

# %%
zscore(df["quality"])
# Out:
# 0      -0.787823
# 1      -0.787823
# 2      -0.787823
# 3       0.450848
# 4      -0.787823
#           ...
# 1594   -0.787823
# 1595    0.450848
# 1596    0.450848
# 1597   -0.787823
# 1598    0.450848
# Name: quality, Length: 1599, dtype: float64

# %%
df["zquality"] = zscore(df["quality"])

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  zquality
# 0      9.4        5 -0.787823
# ...

# %%
df[(df["zquality"]<-3)|(df["zquality"]>3)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 459            11.6             0.580         0.66            2.20     0.0740
# 517            10.4             0.610         0.49            2.10     0.1261
# 690             7.4             1.015         0.00            3.65     0.0970
# 832            10.4             0.440         0.42            1.50     0.1261
# 899             8.3             1.015         0.02            3.40     0.0840
# 1299            7.6             1.015         0.00            2.10     0.1261
# 1374            6.8             0.815         0.00            1.20     0.1261
# 1469            7.3             0.980         0.05            2.10     0.0610
# 1478            7.1             0.875         0.05            3.65     0.0820
# 1505            6.7             0.760         0.02            1.80     0.0780
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df[(df["quality"]<qlow)|(df["quality"]>=8)]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 267            7.90             0.350         0.46            3.60     0.0780
# 278           10.30             0.320         0.45            3.65     0.0730
# 390            5.60             0.850         0.05            1.40     0.0540
# 440           12.35             0.310         0.72            2.20     0.0720
# 455           11.30             0.620         0.67            3.65     0.0860
# 459           11.60             0.580         0.66            2.20     0.0740
# 481            9.40             0.300         0.56            2.80     0.0800
# 495           10.70             0.350         0.53            2.60     0.0700
# 498           10.70             0.350         0.53            2.60     0.0700
# 517           10.40             0.610         0.49            2.10     0.1261
# 588            5.00             0.420         0.24            2.00     0.0600
# ...

# %%
df[(df["quality"]<qlow)|(df["quality"]>=8)].index
# Out:
# Int64Index([ 267,  278,  390,  440,  455,  459,  481,  495,  498,  517,  588,
#              690,  828,  832,  899, 1061, 1090, 1120, 1202, 1269, 1299, 1374,
#             1403, 1449, 1469, 1478, 1505, 1549],
#            dtype='int64')

# %%
df= df.drop(df[(df["quality"]<qlow)|(df["quality"]>=8)].index)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.drop("zquality",axis=1)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df = df.drop("zquality",axis=1)

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# # Separation of data

# %%
X = df.drop("quality",axis=1)

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y = df["quality"]

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1571, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=2)

# %%
X.shape,X_train.shape,X_test.shape
# Out:
# ((1571, 11), (1256, 11), (315, 11))

# %%
y.shape,y_train.shape,y_test.shape
# Out:
# ((1571,), (1256,), (315,))

# %% [markdown]
# # Model Building

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier()

# %%
knn
# Out:
# KNeighborsClassifier()

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.score(X_test,y_test)
# Out:
# C:\Users\91970\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# 0.5111111111111111

# %% [markdown]
# # Auto ml

# %%
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,RandomForestClassifier

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.svm import SVC

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
gbc=GradientBoostingClassifier()

# %%
abc=AdaBoostClassifier()

# %%
rfc=RandomForestClassifier()

# %%
svm=SVC()

# %%
knn=KNeighborsClassifier()

# %%
dtc=DecisionTreeClassifier()

# %%
lreg=LogisticRegression()

# %%
clist=[gbc,abc,rfc,svm,knn,dtc,lreg]

# %%
clist
# Out:
# [GradientBoostingClassifier(),
#  AdaBoostClassifier(),
#  RandomForestClassifier(),
#  SVC(),
#  KNeighborsClassifier(),
#  DecisionTreeClassifier(),
#  LogisticRegression()]

# %%
import time

# %%
for i in clist:
    print(i,end = "==")
    i.fit(X_train,y_train)
    m=i.score(X_test,y_test)
    print(m)
    time.sleep(0.6)
# Out:
# GradientBoostingClassifier()==0.6412698412698413
# AdaBoostClassifier()==0.5047619047619047
# RandomForestClassifier()==0.7111111111111111
# SVC()==0.44761904761904764
# KNeighborsClassifier()==0.5111111111111111
# C:\Users\91970\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# DecisionTreeClassifier()==0.5619047619047619
# LogisticRegression()==0.5936507936507937
# C:\Users\91970\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# ...

# %%
rlist=[]
for i in range(0,51):
    print("random_state=",i)
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=i)
    for m in clist:
        print(m,end = "==")
        m.fit(X_train,y_train)
        s=m.score(X_test,y_test)
        print(s)
        rlist.append(s)
        print("********************************************************************************")
        print("Max = ",max(rlist))
        rlist.index(max(rlist))
        print("Max_index =",rlist.index(max(rlist)))
        print("*********************************************************************************")
# Out:
# random_state= 0
# GradientBoostingClassifier()==0.6412698412698413
# ********************************************************************************
# Max =  0.6412698412698413
# Max_index = 0
# *********************************************************************************
# AdaBoostClassifier()==0.5206349206349207
# ********************************************************************************
# Max =  0.6412698412698413
# Max_index = 0
# *********************************************************************************
# RandomForestClassifier()==0.7174603174603175
# ********************************************************************************
# Max =  0.7174603174603175
# Max_index = 2
# *********************************************************************************
# SVC()==0.5238095238095238
# ********************************************************************************
# Max =  0.7174603174603175
# Max_index = 2
# ...
